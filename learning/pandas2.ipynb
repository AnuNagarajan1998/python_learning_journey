# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\anura\Downloads\products_data.xlsx")

expensive = df[df["Price"] > 20000]
low_stock = df[df["Stock"] < 10]
Electronics = df[df["Category"] == "Electronics"]
df1 = df[(df["Category"] == "Books") & (df["Rating"] > 4.0)]
df2 = df[(df["Category"] == "Toys") & (df["Category"] == "Sports")]
df3 = df.loc[(df["Price"] >= 1000) & (df["Price"] <5000)]
df4 = df.iloc[0:20]
df5 = df4.loc[df["Category"] == "Electronics"]
traget_countries = ["USA", "UK", "Canada"]
df6 = df[df["Country"].isin(traget_countries)]
drop_category = ["Books", "Beauty"]
df7 = df[~df["Category"].isin(drop_category)]


print(df.head())
print()
print(expensive["Price"].count())
print()
print(low_stock["Stock"].count())
print()
print(Electronics.head())
print()
print(df1.head())
print()
print(df2.head())
print()
print(df3.head())
print()
print(df5.head())
print()
print(df6.head())
print()
print(df7.head())
print()
print(df["Category"].unique())
print()
print(df["Country"].nunique())
print()
print(df["Category"].value_counts())
print()
# Out:
#    Product ID         Product Name        Category     Price  Rating  Stock  \
# 0        1001       Cotton T-Shirt        Clothing  14083.16     1.2      4
# 1        1002  Building Blocks Set            Toys   8580.87     2.0    122
# 2        1003       LED Table Lamp  Home & Kitchen   5080.03     2.2    269
# 3        1004     Wireless Earbuds     Electronics  19015.71     3.6     85
# 4        1005      Toy Kitchen Set            Toys   6626.74     1.6    337
#
#      Country
# 0  Australia
# 1         UK
# 2    Germany
# 3         UK
# 4      Japan
#
# 190
#
# 22
#
#     Product ID       Product Name     Category     Price  Rating  Stock  \
# 3         1004   Wireless Earbuds  Electronics  19015.71     3.6     85
# 11        1012    Smartphone Case  Electronics  11568.86     2.1    169
# 19        1020  Bluetooth Speaker  Electronics   4706.24     1.4    142
# 20        1021    Smartphone Case  Electronics  18911.91     4.7    321
# ...
