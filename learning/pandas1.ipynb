# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\my_learning\python\data_cleaning\retail_store_sales.csv")

print(df.head())
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3              NaN
# ...

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\my_learning\python\data_cleaning\retail_store_sales.csv")

print(df.isna().sum())
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                1213
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\my_learning\python\data_cleaning\retail_store_sales.csv")

print(df.isnull().sum())
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                1213
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\my_learning\python\data_cleaning\retail_store_sales.csv")

print(df.notnull().sum())
# Out:
# Transaction ID      12575
# Customer ID         12575
# Category            12575
# Item                11362
# Price Per Unit      11966
# Quantity            11971
# Total Spent         11971
# Payment Method      12575
# Location            12575
# Transaction Date    12575
# Discount Applied     8376
# dtype: int64

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\my_learning\python\data_cleaning\retail_store_sales.csv")

df2 = df.dropna()

print(df.isnull().sum())
print()
print(df2.isnull().sum())
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                1213
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64
#
# Transaction ID      0
# Customer ID         0
# Category            0
# Item                0
# Price Per Unit      0
# Quantity            0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# Discount Applied    0
# dtype: int64

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\my_learning\python\data_cleaning\retail_store_sales.csv")

df1 = df.dropna(subset=["Item"]) #if item is missing remove the entire row


print(df.isnull().sum())
print()
print(df1.isnull().sum())
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                1213
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64
#
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                   0
# Price Per Unit         0
# Quantity               0
# Total Spent            0
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    3783
# dtype: int64

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\my_learning\python\data_cleaning\retail_store_sales.csv")

df1 = df.drop("Item", axis=1) #removes the spcecified column


print(df.isnull().sum())
print()
print(df1.isnull().sum())
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                1213
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64
#
# Transaction ID         0
# Customer ID            0
# Category               0
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\my_learning\python\data_cleaning\retail_store_sales.csv")

df2 = df.fillna(0)
df2 = df2.astype(int)  #error because we are trying to convert the entire dataset to int type


print(df.head())
print()
print(df2.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 6
#       2
#       3 df = pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\my_learning\python\data_cleaning\retail_store_sales.csv")
#       4
#       5 df2 = df.fillna(0)
# ----> 6 df2 = df2.astype(int)
#       7
#       8
#       9 print(df.head())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6538
#    6539         else:
#    6540             # else, only a single dtype is given
# -> 6541             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543             return res.__finalize__(self, method="astype")
#    6544
#
# ...

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\my_learning\python\data_cleaning\retail_store_sales.csv")

numeric_column = df.select_dtypes(include ="number").columns

df1[numeric_column] = df[numeric_column].fillna(0)

text_column = df.select_dtypes(include = ["object","string"]).columns

df1[text_column] = df[text_column].fillna("Unknown")

print(df.head())
print()
print(df1.head())
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3              NaN
# ...

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\my_learning\python\data_cleaning\retail_store_sales.csv")

print(df.iloc[0]) #first row
print()
print(df.iloc[11]) #print 10th row
print()
print(df.iloc[0:5]) #print first 5 rows
print()
print(df.iloc[10:21]) #print 10 through 20
print()
print(df.iloc[:,0:3]) #print 3 columns
print()
print(df.iloc[0:5,0:4]) #first 5 rows and 4 columns
print()
print(df.iloc[4,2]) #5th row 3rd column
print()
print(df.iloc[5:20:5,1:7:2])
# Out:
# Transaction ID         TXN_6867343
# Customer ID                CUST_09
# Category                Patisserie
# Item                   Item_10_PAT
# Price Per Unit                18.5
# Quantity                      10.0
# Total Spent                  185.0
# Payment Method      Digital Wallet
# Location                    Online
# Transaction Date        2024-04-08
# Discount Applied              True
# Name: 0, dtype: object
#
# Transaction ID         TXN_5422631
# Customer ID                CUST_09
# Category             Milk Products
# Item                           NaN
# Price Per Unit                 NaN
# Quantity                       8.0
# Total Spent                   52.0
# Payment Method      Digital Wallet
# Location                  In-store
# Transaction Date        2025-01-12
# Discount Applied              True
# Name: 11, dtype: object
#
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# ...

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\my_learning\python\data_cleaning\retail_store_sales.csv")

print(df.loc[10]) #label 10
print()
print(df.loc[5:15]) # 5 through 15
print()
print(df.loc[:,"Item"]) #column item
print()
print(df.loc[:,["Item","Category","Quantity"]])
print()
print(df.loc[10:20,["Item","Quantity"]])
print()
print(df.loc[0:10,["Transaction ID", "Customer ID"]])
print()
print(df.loc[100,"Item"])
print()
print(df.loc[50:100:50])
# Out:
# Transaction ID      TXN_8776416
# Customer ID             CUST_22
# Category               Butchers
# Item                 Item_3_BUT
# Price Per Unit              8.0
# Quantity                    9.0
# Total Spent                72.0
# Payment Method             Cash
# Location               In-store
# Transaction Date     2024-12-14
# Discount Applied           True
# Name: 10, dtype: object
#
#    Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 5     TXN_7482416     CUST_09     Patisserie           NaN             NaN
# 6     TXN_3652209     CUST_07           Food   Item_1_FOOD             5.0
# 7     TXN_1372952     CUST_21      Furniture           NaN            33.5
# 8     TXN_9728486     CUST_23      Furniture   Item_16_FUR            27.5
# 9     TXN_2722661     CUST_25       Butchers   Item_22_BUT            36.5
# 10    TXN_8776416     CUST_22       Butchers    Item_3_BUT             8.0
# ...

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\my_learning\python\data_cleaning\retail_store_sales.csv")

print(df.loc[:,"Item"].count())
print()
print(df.iloc[:,5].sum())
print()
print(df.describe())
# Out:
# 11362
#
# 66276.0
#
#        Price Per Unit      Quantity   Total Spent
# count    11966.000000  11971.000000  11971.000000
# mean        23.365912      5.536380    129.652577
# std         10.743519      2.857883     94.750697
# min          5.000000      1.000000      5.000000
# 25%         14.000000      3.000000     51.000000
# 50%         23.000000      6.000000    108.500000
# 75%         33.500000      8.000000    192.000000
# max         41.000000     10.000000    410.000000

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\my_learning\python\data_cleaning\retail_store_sales.csv")

df1 = df.loc[df["Quantity"] > 5]
df2 = df.loc[df["Quantity"] > 5,["Item", "Quantity"]]
df3 = df.loc[df["Price Per Unit"] > 20]
df4 = df.loc[df["Price Per Unit"] > 20, ["Item", "Price Per Unit", "Total Spent"]]
df5 = df.loc[df["Total Spent"] > 100]
df6 = df.loc[(df["Quantity"] > 3) & (df["Total Spent"] > 100)]
df7 = df.loc[(df["Quantity"] > 5) | (df["Total Spent"] > 200)]
df8 = df.loc[df["Category"] == "Clothing"]
df9 = df.loc[df["Category"] == "Clothing", ["Item", "Quantity", "Total Spent"]]





print(df1.head())
print()
print(df2.head())
print()
print(df3.head())
print()
print(df4.head())
print()
print(df5.head())
print()
print(df6.head())
print()
print(df7.head())
print()
print(df8.head())
print()
print(df9.head())
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# 5    TXN_7482416     CUST_09     Patisserie           NaN             NaN
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
# 5      10.0        200.0     Credit Card   Online       2023-11-30
#
#   Discount Applied
# 0             True
# 1             True
# 3              NaN
# 4            False
# ...

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\anura\OneDrive\Desktop\my_learning\python\data_cleaning\retail_store_sales.csv")

df1 = df.loc[df["Item"].isna()]
df2 = df.loc[df["Item"].notna()]
df3 = df.loc[df["Item"].isna()  |df["Transaction ID"].isna()]

print(df1.head())
print()
print(df2.head())
print()
print(df3.head())
# Out:
#    Transaction ID Customer ID       Category Item  Price Per Unit  Quantity  \
# 5     TXN_7482416     CUST_09     Patisserie  NaN             NaN      10.0
# 7     TXN_1372952     CUST_21      Furniture  NaN            33.5       NaN
# 11    TXN_5422631     CUST_09  Milk Products  NaN             NaN       8.0
# 15    TXN_1809665     CUST_14      Beverages  NaN            24.5       NaN
# 17    TXN_9634894     CUST_15  Milk Products  NaN             NaN      10.0
#
#     Total Spent  Payment Method  Location Transaction Date Discount Applied
# 5         200.0     Credit Card    Online       2023-11-30              NaN
# 7           NaN  Digital Wallet  In-store       2024-04-02             True
# 11         52.0  Digital Wallet  In-store       2025-01-12             True
# 15          NaN     Credit Card  In-store       2022-05-11              NaN
# 17        275.0  Digital Wallet    Online       2022-04-17              NaN
#
# ...
