# %%
a= 10
b=20
print(a+b)
# Out:
# 30

# %%
name = input("enter you name")
age = int(input("enter you age"))
city = input("Enter you city")
print(f"My name is {name}. I am {age} years old and I live in {city}")
# Out:
# enter you name Anu
# enter you age 27
# Enter you city Yanbu
# My name is Anu. I am 27 years old and I live in Yanbu

# %%
product = "Laptop"
price = 2500
quantity = 2
print(f"I bought {quantity} {product}(s) for {price} SAR each")
# Out:
# I bought 2 Laptop(s) for 2500 SAR each

# %%
name = "Anu"
age = 27
course = "Python"
print(f"My name is {name}, I am {age} years old, and I am learning {course}")
# Out:
# My name is Anu, I am 27 years old, and I am learning Python

# %%
basic_salary = 4000
bonus = 500
total_salary = basic_salary + bonus 
print(f"My basic salary is {basic_salary} SAR and my total salary is {total_salary} SAR")
# Out:
# My basic salary is 4000 SAR and my total salary is 4500 SAR

# %%
customer_name = "Anu"
product = "iPhone"
price = 3000
quantity = 2
total_amount = price * quantity
print(f"Customer: {customer_name}\n"
f"Product: {product}\n"
f"Quantity: {quantity}\n"
f"Total Amount: {total_amount} SAR")
# Out:
# Customer: Anu
# Product: iPhone
# Quantity: 2
# Total Amount: 6000 SAR

# %%
student_name = "Anu"
python_score = 85
sql_score = 90
excel_score = 80
total = python_score+sql_score+excel_score
average = total/3
print(f"Student: {student_name}\n"
f"Python: {python_score:}\n"
f"SQL_score: {sql_score:}\n"
f"Excel_score: {excel_score:}\n"
f"Total: {total}\n"
f"Average: {average: .1f}")
# Out:
# Student: Anu
# Python: 85
# SQL_score: 90
# Excel_score: 80
# Total: 255
# Average:  85.0
