# %%
# addition of two number
def add(a,b):
  return a+b

k=int(input("Enter the first Number"))
l=int(input("Enter the second Number"))

d=add(k,l)
print(d)
# Out:
# Enter the first Number5
# Enter the second Number8
# 13

# %%
# to find min and max numbers from given set of input
def min_max(b):
  return min(b), max(b)

arr = []

print("Enter the input")

arr = list(map(int,input().split()))

low,high = min_max(arr)
print(low,high)
# Out:
# Enter the input
# 5 8 7 1 3 6 9 4 5 2 1 0 5 8 7
# 0 9

# %%
#to check whether a number is prime or not and counting

def is_prime(b):
 out = []
 for i in range(0,len(b)):
  count = 0
  k = 1
  while k != b[i]:
    if b[i] % k == 0:
      count += 1
    k += 1
  if count == 1:
    out.append(b[i])
 return (out)

def counting_prime(c):
  return (len(c))

arr = []

print("Enter the numbers")
arr = list(map(int, input().split()))

result = is_prime(arr)
print(result)
count = counting_prime(result)
print(count)
# Out:
# Enter the numbers
# 2 3 4 5 6 7 8 9 11
# [2, 3, 5, 7, 11]
# 5

# %%
#find compound or simple interest
def calculate_si_ci(p,r,t,m):
    if mode == 'si':
        out = (p*r*t)/100
    elif mode == 'ci':
        out = p*(1+(r/100))**t
    else:
        raise ValueError("Invalid mode. Please enter 'si' or 'ci'.")
    return (out)


pamount = int(input("Enter the principal amount: "))
rate = int(input("Enter the rate: "))
year = int(input("Enter the number of years: "))
mode = input("Enter if you want to calculate simple or compound interest as si/ci:")

si = calculate_si_ci(pamount,rate,year,mode)
ci = calculate_si_ci(pamount,rate,year,mode)
if mode == 'si':
    print(f"The simple interest is {si}")
elif mode == 'ci':
    print(f"The compound interest is {ci}")
# Out:
# Enter the principal amount: 500000
# Enter the rate: 18
# Enter the number of years: 5
# Enter if you want to calculate simple or compound interest as si/ci:ci
# The compound interest is 1143878.8783999998
